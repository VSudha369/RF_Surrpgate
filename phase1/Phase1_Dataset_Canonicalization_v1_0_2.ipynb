# %% [markdown]
# # Phase 1 v1.0.2 — Native WiSig ManyTx
#
# Recommended runtime: **CPU / High-RAM**. This uses the source-authentic `ManyTx.pkl.zip` and preserves native `L=256`.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %%
# !rm -rf /content/RF_Surrpgate
# !git clone https://github.com/VSudha369/RF_Surrpgate.git /content/RF_Surrpgate
# %cd /content/RF_Surrpgate/phase1

# %%
# !python Phase1_Dataset_Canonicalization_v1_0_2.py --discover

# %%
# !cp phase1_config_v1_0_2_template.json /content/phase1_config_wisig.json
import json
with open('/content/phase1_config_wisig.json') as f:
    cfg = json.load(f)
cfg

# %%
# Run after verifying the ManyTx source path shown above.
# !python Phase1_Dataset_Canonicalization_v1_0_2.py --config /content/phase1_config_wisig.json --dataset wisig
