# %% [markdown]
# # Phase 1 — Dataset Canonicalization & Storage v1.0.1
#
# Recommended: CPU / High-RAM Colab runtime. Mount Drive in the notebook kernel before launching the Phase-1 subprocess.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %%
# !rm -rf /content/RF_Surrpgate
# !git clone https://github.com/VSudha369/RF_Surrpgate.git /content/RF_Surrpgate
# %cd /content/RF_Surrpgate/phase1

# %%
# !python Phase1_Dataset_Canonicalization_v1_0_1.py --discover

# %%
# !python Phase1_Dataset_Canonicalization_v1_0_1.py --write-config-template /content/phase1_config.json
